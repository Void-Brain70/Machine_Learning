# %% [markdown]
# <a href="https://colab.research.google.com/github/Void-Brain70/Machine_Learning/blob/main/MVLR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# dataset

import os
import io
import pandas as pd
import matplotlib.pyplot as plt # for ploting
import seaborn as sns # for ploting 3D data
# %matplotlib inline

df = pd.read_csv('/content/petrol_consumption.csv')
df.head()
# Out:
#    Petrol_tax  Average_income  ...  Population_Driver_licence(%)  Petrol_Consumption
# 0         9.0            3571  ...                         0.525                 541
# 1         9.0            4092  ...                         0.572                 524
# 2         9.0            3865  ...                         0.580                 561
# 3         7.5            4870  ...                         0.529                 414
# 4         8.0            4399  ...                         0.544                 410
#
# [5 rows x 5 columns]

# %%
df = df.rename(columns={'Petrol_tax': 'x1', 'Average_income': 'x2', 'Paved_Highways': 'x3', 'Population_Driver_licence(%)': 'x4', 'Petrol_Consumption': 'y'})
df.head()
# Out:
#     x1    x2    x3     x4    y
# 0  9.0  3571  1976  0.525  541
# 1  9.0  4092  1250  0.572  524
# 2  9.0  3865  1586  0.580  561
# 3  7.5  4870  2351  0.529  414
# 4  8.0  4399   431  0.544  410

# %%
x1 = df.x1
x2 = df.x2 
x3 = df.x3 
x4 = df.x4
y  = df.y

# %%
# parameter initialization
theta = [425.599332,-40.016660,-0.065413,-0.004741,1341.862121]

print(theta)
# Out:
# [425.599332, -40.01666, -0.065413, -0.004741, 1341.862121]

# %%
def plot_cost_vs_iteration(costs):
    plt.plot([i for i in range(len(j))],j)
    plt.title("Cost vs Iteration")
    plt.xlabel("Iteration")
    plt.ylabel("Cost")
    plt.show()

# %%
J = 50
theta = [425.599332,-40.016660,-0.065413,-0.004741,1341.862121]
for i in range(30):
    # hypothesis function
    
    h = []
    m = len(y)
    for i in range(m):
        h.append(theta[0] + theta[1]*x1[i] + theta[2]*x2[i] + theta[3]*x3[i] + theta[4]*x4[i])

    print("Hypothesis Function Value is: ", h)

    # cost

    error = 0
    for i in range(m):
        error = error + (h[i] - y[i]) ** 2

    J = (1/ (2*m))*error

    print("Cost function value is", J)


    # Gradient Descent
    sum0 = 0
    sum1 = 0
    sum2 = 0
    sum3 = 0
    sum4 = 0
    for i in range(m):
        sum0 = sum0 + (h[i] - y[i])
        sum1 = sum1 + (h[i] - y[1])*x1[i]
        sum2 = sum2 + (h[i] - y[i])*x2[i]
        sum3 = sum3 + (h[i] - y[i])*x3[i]
        sum4 = sum4 + (h[i] - y[i])*x4[i]


    alpha = 0.001
    theta[0] = theta[0] - (alpha/m)*sum0
    theta[1] = theta[1] - (alpha/m)*sum1
    theta[2] = theta[2] - (alpha/m)*sum2
    theta[3] = theta[3] - (alpha/m)*sum3
    theta[4] = theta[4] - (alpha/m)*sum4

    print("Updated parameters are: ", theta)
# Out:
# Hypothesis Function Value is:  [526.9689665249999, 559.3982792119999, 583.3889511799999, 505.612043009, 545.643887824, 435.88000409099993, 306.44793357099996, 502.07250891300004, 483.755946009, 550.7154597919999, 501.26769413, 427.3891315249999, 567.7620184539999, 570.4092969449999, 639.2839465679999, 600.3386409059999, 597.5643392119998, 604.4814983399999, 780.4601646039999, 681.447134917, 697.554395223, 584.4599878419999, 419.202765831, 458.447228557, 513.208009671, 529.519826824, 589.665811308, 607.8759510589998, 558.6573071229999, 469.389554653, 569.727365678, 584.5742970729999, 649.7720549379999, 620.343860187, 511.60604592699997, 720.479763309, 636.1099454859999, 646.6281689059999, 721.8140192230001, 744.480967312, 672.4724637459999, 642.9082731229998, 656.1161359629999, 569.798233468, 735.1881403120001, 520.1750530909999, 681.0910623829999, 567.5777697529999]
# Cost function value is 1999.2209313872777
# ...
